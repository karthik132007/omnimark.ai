# %%
import os
import sys

# Ensure repo root is on sys.path for absolute imports like `backend.*`
repo_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

# %%
import pandas as pd

# %%
from backend.db import db
